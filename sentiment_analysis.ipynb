# %%
import pandas as pd
from src.scripts.sentiment_analysis import *
from scipy import stats
from collections import defaultdict

# %%
adapted_movies_df = pd.read_csv('data/adapted_movies.csv')
adapted_movies_df = adapted_movies_df.dropna(subset=['MovieBoxOffice', 'MoviePlot']).reset_index(drop=True)
adapted_movies_df
# Out:
#       wikipedia_id                    MovieName  MovieYear  MovieBoxOffice  \
# 0             3333        The Birth of a Nation       1915      50000000.0
# 1         21135479       Little Lord Fauntleroy       1921        900000.0
# 2            73930                        Greed       1924        274827.0
# 3           308930     The Phantom of the Opera       1925       2000000.0
# 4         31667694                   Beau Ideal       1931        575000.0
# ...            ...                          ...        ...             ...
# 997       27504596                  White Night       2009       6171057.0
# 998       30470501         Into The White Night       2010       4593914.0
# 999       32621340                   The Client       2011      15780280.0
# 1000      35020822                     Helpless       2012      16175929.0
# 1001        402866  The Hunchback of Notre Dame       1996     325338851.0
#
#       MovieRuntime                                    MovieLanguage  \
# 0            190.0                    Silent film, English Language
# 1            112.0                    Silent film, English Language
# 2            246.0                    Silent film, English Language
# 3            106.0  Silent film, English Language, American English
# 4              NaN                                              NaN
# ...            ...                                              ...
# 997          135.0                                  Korean Language
# 998          149.0                                Japanese Language
# 999          122.0                                  Korean Language
# 1000         117.0                                  Korean Language
# 1001          90.0                                 English Language
#
#                          MovieCountries  \
# 0              United States of America
# 1              United States of America
# 2              United States of America
# 3     United States of America, England
# 4              United States of America
# ...                                 ...
# 997                         South Korea
# 998                               Japan
# 999                         South Korea
# 1000                        South Korea
# 1001           United States of America
#
#                                              MovieGenre  \
# 0     Silent film, Indie, Costume drama, Epic, Black...
# 1     Silent film, Drama, Comedy, Black-and-white, F...
# 2                   Silent film, Drama, Black-and-white
# 3                            Horror, Silent film, Drama
# 4                     Romance Film, Adventure, War film
# ...                                                 ...
# 997                     Thriller, Mystery, Romance Film
# 998                Drama, Japanese Movies, World cinema
# 999             Crime Fiction, Mystery, Thriller, Drama
# 1000                                  Thriller, Mystery
# 1001  Family Film, Drama, Romance Film, Musical, Ani...
#
#                    BookAuthor  \
# 0           Thomas Dixon, Jr.
# 1     Frances Hodgson Burnett
# 2                Frank Norris
# 3               Gaston Leroux
# 4                  P. C. Wren
# ...                       ...
# 997           Keigo Higashino
# 998           Keigo Higashino
# 999              John Grisham
# 1000            Miyuki Miyabe
# 1001              Victor Hugo
#
#                                               BookTitle  BookStartYear  \
# 0     The Clansman: A Historical Romance of the Ku K...         1905.0
# 1                                Little Lord Fauntleroy         1885.0
# 2                                              McTeague         1899.0
# 3                              The Phantom of the Opera         1909.0
# 4                                            Beau Geste         1924.0
# ...                                                 ...            ...
# 997                      Journey Under the Midnight Sun         1999.0
# 998                      Journey Under the Midnight Sun         1999.0
# 999                                          The Client         1993.0
# 1000                                  All She Was Worth         1992.0
# 1001                        The Hunchback of Notre-Dame         1482.0
#
#      BookEndYear                                    BookDescription  \
# 0           1905                                                NaN
# 1           1886  Illustrated. Frances Hodgson Burnett's charact...
# 2           1899                                                NaN
# 3           1910                                                NaN
# 4           1924  Three noble English brothers battle a sadistic...
# ...          ...                                                ...
# 997         1999                                                NaN
# 998         1999                                                NaN
# 999         1993                                                NaN
# 1000        1992  Here is a deftly written thriller that is also...
# 1001        1482                                                NaN
#
#       BookRating  BookRatingNb BookLanguage  MovieRating  MovieRatingNb  \
# 0            NaN           NaN          NaN          6.1          26959
# 1           3.85       18137.0          NaN          6.8            384
# 2           3.68        5410.0          eng          8.0          11078
# 3           3.97      189814.0          NaN          7.5          20708
# 4           4.01        3047.0          NaN          4.9            251
# ...          ...           ...          ...          ...            ...
# 997          NaN           NaN          NaN          6.5           1475
# 998          NaN           NaN          NaN          6.5            518
# 999         4.01      378641.0          eng          6.8           2040
# 1000        3.69        2921.0          NaN          6.7           2662
# 1001        4.00      162555.0          eng          1.9             84
#
#                                               MoviePlot
# 0      The film follows two juxtaposed families: the...
# 1     Cedric Errol is a poor American boy who finds ...
# 2     {{quote box}} Trina & McTeague The film opens ...
# 3     :The scenario presented is based on the genera...
# 4     The hero, John Geste, joins the French Foreign...
# ...                                                 ...
# 997   Kim Si-hoo, a pawnbroker is found murdered in ...
# 998   A pawn shop owner in Osaka is murdered, but du...
# 999   On his wedding anniversary, Han Chul-min  driv...
# 1000  South Korea, 2009. A few days before their wed...
# 1001   In 1482 Paris, Clopin, a gypsy puppeteer, nar...
#
# [1002 rows x 19 columns]

# %% [markdown]
# ### sentiment analysis

# %%
algorithms = [vader_sentiment_analysis, textblob_sentiment_analysis, BERT_sentiment_analysis]
sentiments_adapted = sentiment_analysis(adapted_movies_df, algorithms)
sentiments_adapted.to_csv('data/adapted_movies_sentiments.csv', index=False)
sentiments_adapted

# %%
adapted_movies_df = pd.read_csv('data/adapted_movies.csv')
adapted_movies_df = adapted_movies_df.dropna(subset=['BookDescription']).reset_index(drop=True)

algorithms = [vader_sentiment_analysis, textblob_sentiment_analysis, BERT_sentiment_analysis]
sentiment_book = sentiment_analysis(adapted_movies_df, algorithms, 'BookDescription')
sentiment_book.to_csv('data/adapted_books_sentiments.csv', index=False)
sentiment_book

# %% [markdown]
# ### correlation between book and movie plot

# %%
movie_sentiments = pd.read_csv('data/adapted_movies_sentiments.csv')
book_sentiments = pd.read_csv('data/adapted_books_sentiments.csv')

# %%
sentiments = movie_sentiments.merge(book_sentiments, on='wikipedia_id', how='inner', suffixes=('_movie', '_book'))

# %%
correlations = defaultdict(float)
metrics = [ 'compound', 'neg', 'neu', 'pos', 'polarity', 'subjectivity' , 'sadness', 'joy', 'love', 'anger', 'surprise', 'fear' ]
for metric in metrics:
    pearson_corr, pearson_pval = stats.pearsonr(sentiments[metric + "_book"],sentiments[metric + "_movie"])
    spearman_corr, spearman_pval = stats.spearmanr(sentiments[metric + "_book"],sentiments[metric + "_movie"])
    correlations[metric] = { 'pearson_correlation': pearson_corr,
                            'pearson_pval': pearson_pval,
                            'spearman_correlation': spearman_corr,
                            'spearman_pval': spearman_pval}
correlations = pd.DataFrame(correlations).T

# %%
html_table = correlations.to_html(classes="table table-striped", index=True)

with open("table.html", "w") as file:
    file.write(html_table)

correlations
# Out:
#               pearson_correlation  pearson_pval  spearman_correlation  \
# compound                 0.258787  4.131332e-05              0.298513
# neg                      0.326173  1.762005e-07              0.317920
# neu                      0.188660  3.031111e-03              0.205208
# pos                      0.250243  7.492433e-05              0.243133
# polarity                 0.067432  2.931340e-01              0.111599
# subjectivity             0.042274  5.101544e-01              0.049393
# sadness                  0.119381  6.207860e-02              0.146411
# joy                      0.139826  2.865599e-02              0.147467
# love                     0.027217  6.716239e-01              0.054519
# anger                    0.157965  1.330646e-02              0.149057
# surprise                -0.060540  3.453642e-01              0.032239
# fear                     0.306215  1.026951e-06              0.362064
#
#               spearman_pval
# compound       1.960190e-06
# neg            3.709767e-07
# neu            1.237747e-03
# pos            1.210390e-04
# polarity       8.127898e-02
# subjectivity   4.415108e-01
# sadness        2.188576e-02
# joy            2.094027e-02
# love           3.955322e-01
# anger          1.958333e-02
# surprise       6.155442e-01
# fear           5.300071e-09

# %%
df = pd.DataFrame()
df['Significant'] = correlations['spearman_pval'] < 0.05
df['Category'] = correlations.index
df['Correlation'] = correlations['spearman_correlation']
df.sort_values(by='Correlation', ascending=False, inplace=True)
plot_correlation(df)
