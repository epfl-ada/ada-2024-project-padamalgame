# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from src.scripts.merge_cmu import clean_cmu

# %%
# Load the dataset CMU
cmu_movies = clean_cmu("MovieSummaries/movie.metadata.tsv")

# Load the dataset merge_imdb
df = pd.read_csv('data/merge_imdb.csv')

# %%
# Get the top 25 authors by the number of movies
top_authors = df['author_book'].value_counts().head(25)

# Plot the bar chart
plt.figure(figsize=(8, 4))
top_authors.plot(kind='bar')
plt.title('Number of Movies per Author')
plt.xlabel('Author')
plt.ylabel('Number of Movies')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
jane_austen = df[df['author_book'] == 'Jane Austen']
jane_austen.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# aisha                       1
# emma                        1
# frompradatonada             1
# kandukondainkandukondain    1
# pride&prejudice             1
# prideandprejudice           1
# rajaaurrunk                 1
# senseandsensibility         1
# theprinceandthepauper       2
# theprinceandthesurfer       1
# Name: movie_name, dtype: int64

# %%
burroughs = df[df['author_book'] == 'Edgar Rice Burroughs']
burroughs.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# adventuresoftarzan           1
# attheearth'score             1
# johncarter                   1
# junglegirl                   1
# perilsofnyoka                1
# tarzan                       1
# tarzan'sdeadlysilence        1
# tarzan'sdesertmystery        1
# tarzan'sfightforlife         1
# tarzan'sgreatestadventure    1
# tarzan'shiddenjungle         1
# tarzan'smagicfountain        1
# tarzan'snewyorkadventure     1
# tarzan'speril                1
# tarzan'ssavagefury           1
# tarzan'ssecrettreasure       1
# tarzan'sthreechallenges      1
# tarzan,theapeman             1
# tarzanandhismate             1
# tarzanandtheamazons          1
# tarzanandthebrownprince      1
# tarzanandthegoldenlion       1
# tarzanandthegreatriver       1
# tarzanandthehuntress         1
# tarzanandthejungleboy        1
# tarzanandtheleopardwoman     1
# tarzanandthelostcity         1
# tarzanandthelostsafari       1
# tarzanandthemermaids         1
# ...

# %%
stoker = df[df['author_book'] == 'Bram Stoker']
stoker.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# blacula                            1
# bloodfordracula                    1
# bloodfromthemummy'stomb            1
# bloodofdracula'scastle             1
# bramstoker'sdracula                1
# countdracula                       1
# dracula                            3
# dracula'sdaughter                  1
# dracula2000                        1
# dracula3000                        1
# dracula3d                          1
# dracula:deadandlovingit            1
# dracula:pagesfromavirgin'sdiary    1
# dracula:princeofdarkness           1
# draculaa.d.1972                    1
# draculahasrisenfromthegrave        1
# draculavs.frankenstein             1
# houseofdracula                     1
# loveatfirstbite                    1
# scarsofdracula                     1
# screamblaculascream                1
# sonofdracula                       1
# tastethebloodofdracula             1
# theawakening                       1
# thebridesofdracula                 1
# ...

# %%
dickens = df[df['author_book'] == 'Charles Dickens']
dickens.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# ataleoftwocities          2
# bleakhouse                1
# boycalledtwist            1
# davidcopperfield          1
# doriangray                2
# greatexpectations         5
# nicholasnickleby          1
# oliver!                   1
# oliver&company            1
# olivertwist               5
# themysteryofedwindrood    1
# theoldcuriosityshop       1
# thepickwickpapers         1
# thepictureofdoriangray    2
# twist                     1
# Name: movie_name, dtype: int64

# %%
grey = df[df['author_book'] == 'Zane Grey']
grey.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# codeofthewest             1
# desertgold                1
# driftfence                1
# fightingcaravans          1
# forlornriver              1
# heritageofthedesert       1
# nevada                    2
# rollalong,cowboy          1
# stairsofsand              1
# sunsetpass                1
# thearizonaraiders         1
# theduderanger             1
# thelastoftheduanes        1
# thelastround-up           1
# thelightofwesternstars    1
# thethunderingherd         2
# thevanishingamerican      1
# thewaterhole              1
# tothelastman              2
# underthetontorim          1
# wagonwheels               1
# wandererofthewasteland    1
# wildhorsemesa             1
# Name: movie_name, dtype: int64

# %%
wells = df[df['author_book'] == 'H. G. Wells']
wells.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# firstmeninthemoon           1
# foodofthegodsii             1
# invisibleagent              1
# islandoflostsouls           1
# kipps                       1
# terrorisaman                1
# thefirstmeninthemoon        1
# thefoodofthegods            1
# thehistoryofmr.polly        1
# theinvisibleman             1
# theinvisibleman'srevenge    1
# theinvisiblemanreturns      1
# theinvisiblewoman           1
# theislandofdr.moreau        2
# thetimemachine              2
# thewaroftheworlds           1
# thingstocome                1
# villageofthegiants          1
# waroftheworlds              1
# waroftheworlds:goliath      1
# Name: movie_name, dtype: int64

# %%
shelley = df[df['author_book'] == 'Mary Shelley']
shelley.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# abbottandcostellomeetfrankenstein    1
# brideoffrankenstein                  1
# frankenstein                         1
# frankenstein1970                     1
# frankenstein:dayofthebeast           1
# frankensteinandthemonsterfromhell    1
# frankensteincreatedwoman             1
# frankensteinisland                   1
# frankensteinmeetsthewolfman          1
# frankensteinmustbedestroyed          1
# frankensteinunbound                  1
# houseoffrankenstein                  1
# ladyfrankenstein                     1
# maryshelley'sfrankenstein            1
# sonoffrankenstein                    1
# thebride                             1
# thecurseoffrankenstein               1
# theghostoffrankenstein               1
# thehorroroffrankenstein              1
# therevengeoffrankenstein             1
# youngfrankenstein                    1
# Name: movie_name, dtype: int64

# %%
verne = df[df['author_book'] == 'Jules Verne']
verne.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# 20,000leaguesunderthesea                  2
# aroundtheworldin80days                    1
# captainnemoandtheunderwatercity           1
# fiveweeksinaballoon                       1
# flightofthelostballoon                    1
# fromtheearthtothemoon                     1
# insearchofthecastaways                    1
# journey2:themysteriousisland              1
# journeytothecenteroftheearth              2
# julesverne'srockettothemoon               1
# masteroftheworld                          1
# mysteriousisland                          3
# theblackhole                              1
# themysteriousisland                       1
# thethreestoogesgoaroundtheworldinadaze    1
# Name: movie_name, dtype: int64

# %%
hugo = df[df['author_book'] == 'Victor Hugo']
hugo.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# ezhaipadumpadu             1
# lesmisérables              8
# quasimodod'elparis         1
# seadevils                  1
# thedarlingofparis          1
# thehunchbackofnotredame    5
# Name: movie_name, dtype: int64

# %%
stevenson = df[df['author_book'] == 'Robert Louis Stevenson']
stevenson.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# animaltreasureisland       1
# kidnapped                  4
# longjohnsilver             1
# muppettreasureisland       1
# piratesoftreasureisland    1
# returntotreasureisland     1
# treasureisland             7
# treasureplanet             1
# Name: movie_name, dtype: int64

# %%
twain = df[df['author_book'] == 'Mark Twain']
twain.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# aconnecticutyankee                       1
# aconnecticutyankeeinkingarthur'scourt    2
# akidinkingarthur'scourt                  1
# blackknight                              1
# huckleberryfinn                          2
# theadventuresofhuckfinn                  1
# theadventuresofhuckleberryfinn           2
# theadventuresofmarktwain                 1
# theadventuresoftomsawyer                 1
# tomandhuck                               1
# tomsawyer                                3
# unidentifiedflyingoddball                1
# Name: movie_name, dtype: int64

# %%
kyne = df[df['author_book'] == 'Peter B. Kyne']
kyne.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# action                    1
# atsword'spoint            1
# markedmen                 1
# revengeofthemusketeers    1
# thefourmusketeers         1
# themusketeer              1
# thethreegodfathers        1
# thethreemusketeers        8
# threegodfathers           1
# Name: movie_name, dtype: int64

# %%
christie = df[df['author_book'] == 'Agatha Christie']
christie.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# andthentherewerenone        1
# appointmentwithdeath        1
# deathonthenile              1
# desyatnegrityat             1
# evilunderthesun             1
# gumnaam                     1
# identity                    1
# murderatthegallop           1
# murdermostfoul              1
# murderontheorientexpress    1
# shubhomahurat               1
# tenlittleindians            2
# themirrorcrack'd            1
# Name: movie_name, dtype: int64

# %%
maugham = df[df['author_book'] == 'W. Somerset Maugham']
maugham.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# adorablejulia           1
# beingjulia              1
# christmasholiday        1
# ofhumanbondage          3
# thehourbeforethedawn    1
# themagician             1
# themoonandsixpence      1
# thepaintedveil          2
# therazor'sedge          2
# theseventhsin           1
# Name: movie_name, dtype: int64

# %%
doyle = df[df['author_book'] == 'Arthur Conan Doyle']
doyle.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# beessaalbaad                     1
# returntothelostworld             1
# sherlockholmes                   2
# theadventuresofsherlockholmes    1
# thehoundofthebaskervilles        5
# thelostworld                     3
# thespeckledband                  1
# Name: movie_name, dtype: int64

# %%
fleming = df[df['author_book'] == 'Ian Fleming']
fleming.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# casinoroyale                   2
# diamondsareforever             1
# dr.no                          1
# fromrussiawithlove             1
# goldfinger                     1
# liveandletdie                  1
# moonraker                      1
# neversayneveragain             1
# onhermajesty'ssecretservice    1
# themanwiththegoldengun         1
# thespywholovedme               1
# thunderball                    1
# youonlylivetwice               1
# Name: movie_name, dtype: int64

# %%
#il s'agit d'alexandre dumas
pere = df[df['author_book'] == ' père']
pere.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# montecristo                 1
# padayottam                  1
# thecountofmontecristo       3
# thefifthmusketeer           1
# theironmask                 1
# themanintheironmask         3
# thereturnofthemusketeers    1
# thesonofmontecristo         1
# veta                        1
# Name: movie_name, dtype: int64

# %%
king = df[df['author_book'] == 'Stephen King']
king.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# areturntosalem'slot    1
# carrie                 1
# christine              1
# dreamcatcher           1
# firestarter            1
# misery                 1
# petsematary            1
# silverbullet           1
# thedeadzone            1
# thegreenmile           1
# theshining             1
# Name: movie_name, dtype: int64

# %%
crichton = df[df['author_book'] == 'Michael Crichton']
crichton.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# congo                        1
# disclosure                   1
# jurassicpark                 1
# jurassicparkiii              1
# risingsun                    1
# sphere                       1
# the13thwarrior               1
# theandromedastrain           1
# thelostworld:jurassicpark    1
# theterminalman               1
# timeline                     1
# Name: movie_name, dtype: int64

# %%
hemingway = df[df['author_book'] == 'Ernest Hemingway']
hemingway.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# afarewelltoarms        2
# captainkhorshid        1
# forwhomthebelltolls    1
# islandsinthestream     1
# thebreakingpoint       1
# thegunrunners          1
# theoldmanandthesea     1
# thesunalsorises        1
# tohaveandhavenot       1
# Name: movie_name, dtype: int64

# %%
leonard = df[df['author_book'] == 'Elmore Leonard']
leonard.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# becool            1
# catchaser         1
# getshorty         1
# hombre            1
# jackiebrown       1
# outofsight        1
# thebigbounce      2
# touch             1
# valdeziscoming    1
# Name: movie_name, dtype: int64

# %%
greene = df[df['author_book'] == 'Graham Greene']
greene.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# brightonrock           1
# ourmaninhavana         1
# thecomedians           1
# theendoftheaffair      2
# thefugitive            1
# theheartofthematter    1
# thehonoraryconsul      1
# thequietamerican       2
# Name: movie_name, dtype: int64

# %%
london = df[df['author_book'] == 'Jack London']
london.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# adventure                        1
# callofthewild                    1
# challengetowhitefang             1
# theadventuresofmartineden        1
# theassassinationbureau           1
# thecallofthewild                 2
# theseawolf                       1
# whitefang                        1
# whitefang2:mythofthewhitewolf    1
# Name: movie_name, dtype: int64

# %%
matheson = df[df['author_book'] == 'Richard Matheson']
matheson.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# iamlegend                      1
# somewhereintime                1
# stirofechoes                   1
# theincredibleshrinkingman      1
# theincredibleshrinkingwoman    1
# thelastmanonearth              1
# thelegendofhellhouse           1
# theomegaman                    1
# theyoungwarriors               1
# whatdreamsmaycome              1
# Name: movie_name, dtype: int64

# %%
hardy = df[df['author_book'] == 'Thomas Hardy']
hardy.groupby('movie_name')['movie_name'].count()
# Out:
# movie_name
# dulhanekraatki            1
# farfromthemaddingcrowd    2
# jude                      1
# tess                      1
# tessofthed'urbervilles    1
# theclaim                  1
# themayorofcasterbridge    1
# trishna                   1
# Name: movie_name, dtype: int64
