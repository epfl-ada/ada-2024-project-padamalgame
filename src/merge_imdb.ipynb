# %%
import pandas as pd
merged_cmu = pd.read_csv("merge_cmu.csv")
merged_cmu
# Out:
#             movie_name  movie_date   box_office  runtime  \
# 0          marypoppins        1964  102272727.0    139.0
# 1     mysteriousisland        1982          NaN    100.0
# 2               juarez        1939          NaN    125.0
# 3      thegreatsantini        1979    4702575.0    115.0
# 4            thecastle        1968          NaN     88.0
# ...                ...         ...          ...      ...
# 2321           ivanhoe        1913          NaN      NaN
# 2322           ivanhoe        1913          NaN      NaN
# 2323         risingsun        1993  107198790.0    129.0
# 2324         thedeluge        1974          NaN    315.0
# 2325   thefourfeathers        1939          NaN    130.0
#
#                                 language                 countries  \
# 0                       English Language  United States of America
# 1                      Standard Mandarin                 Hong Kong
# 2     English Language, Spanish Language  United States of America
# 3                       English Language  United States of America
# 4                        German Language              West Germany
# ...                                  ...                       ...
# 2321                    English Language            United Kingdom
# 2322                    English Language            United Kingdom
# 2323                    English Language  United States of America
# 2324                     Polish Language                    Poland
# 2325                    English Language   England, United Kingdom
#
#                                                  genres         author_book  \
# 0     Children's/Family, Musical, Fantasy, Comedy, D...       P. L. Travers
# 1     Action/Adventure, Wuxia, Martial Arts Film, Ch...         Jules Verne
# 2     Costume drama, Biographical film, Historical f...     Bertita Harding
# 3                                   Family Drama, Drama          Pat Conroy
# 4                                        Mystery, Drama         Franz Kafka
# ...                                                 ...                 ...
# 2321               Silent film, Drama, Historical drama    Sir Walter Scott
# 2322               Silent film, Drama, Historical drama    Sir Walter Scott
# 2323  Thriller, Crime Fiction, Mystery, Drama, Suspe...    Michael Crichton
# 2324                                           War film  Henryk Sienkiewicz
# 2325  Adventure, War film, Action/Adventure, Drama, ...      A. E. W. Mason
#
#       year_book
# 0     1934–1988
# 1          1874
# 2          1934
# 3          1976
# 4          1926
# ...         ...
# 2321       1820
# 2322       1820
# 2323       1992
# 2324       1886
# 2325       1902
#
# [2326 rows x 9 columns]

# %%
data_folder = "data/"

def clean_title(title):
    return title.lower().replace(" ", "")

def merge_imdb_id(df):
    titles = pd.read_csv(data_folder + "title.basics.tsv", sep='\t', header=0, usecols=[0, 1, 2, 3, 4, 5], names=['imdbID', 'titleType', 'imdbPrimaryTitle', 'imdbOriginalTitle', 'isAdult', 'imdbYear'], dtype={'isAdult': 'string'})
    
    titles['imdbYear'] = pd.to_numeric(titles['imdbYear'], errors='coerce')
    titles['isAdult'] = pd.to_numeric(titles['isAdult'], errors='coerce')
    titles = titles.dropna()
    titles = titles[titles['titleType'] == 'movie']
    
    titles['imdbOriginalTitle'] = titles['imdbOriginalTitle'].apply(clean_title)
    titles['imdbPrimaryTitle'] = titles['imdbPrimaryTitle'].apply(clean_title)
    mergeOnOriginal = pd.merge(titles, df, how='inner', left_on=['imdbOriginalTitle', 'imdbYear'], right_on=['movie_name', 'movie_date'])
    mergeOnPrimary = pd.merge(titles, df, how='inner', left_on=['imdbPrimaryTitle', 'imdbYear'], right_on=['movie_name', 'movie_date'])
    
    merge = pd.concat([mergeOnOriginal, mergeOnPrimary], axis=0)
    merge = merge.drop_duplicates(subset=['imdbID'])
    merge = merge.drop(['imdbPrimaryTitle', 'imdbOriginalTitle', 'imdbYear', 'titleType'], axis=1)
    
    return merge

merged_imdb_id = merge_imdb_id(merged_cmu)
merged_imdb_id
# Out:
#          imdbID  isAdult                   movie_name  movie_date  \
# 0     tt0000679        0  thefairylogueandradio-plays        1908
# 1     tt0002646        0                     atlantis        1913
# 2     tt0003022        0                      ivanhoe        1913
# 6     tt0004099        0  hismajesty,thescarecrowofoz        1914
# 7     tt0004182        0                    thejungle        1914
# ...         ...      ...                          ...         ...
# 1956  tt1736633        0              oslo,august31st        2011
# 1965  tt2063013        0                 theassassins        2012
# 1966  tt2071441        0            dangerousliaisons        2012
# 1968  tt2308725        0                     helpless        2012
# 1971  tt9799878        0      thehunchbackofnotredame        1996
#
#        box_office  runtime                             language  \
# 0             NaN    120.0                     English Language
# 1             NaN    113.0    English Language, Danish Language
# 2             NaN      NaN        Silent film, English Language
# 6             NaN     60.0                     English Language
# 7             NaN      NaN        Silent film, English Language
# ...           ...      ...                                  ...
# 1956          NaN     95.0                   Norwegian Language
# 1965          NaN      NaN                    Standard Mandarin
# 1966          NaN    110.0  English Language, Standard Mandarin
# 1968   16175929.0    117.0                      Korean Language
# 1971  325338851.0     90.0                     English Language
#
#                           countries  \
# 0          United States of America
# 1                           Denmark
# 2          United States of America
# 6          United States of America
# 7                               NaN
# ...                             ...
# 1956                         Norway
# 1965                          China
# 1966  Singapore, South Korea, China
# 1968                    South Korea
# 1971       United States of America
#
#                                                  genres  \
# 0                          Silent film, Black-and-white
# 1            Silent film, Drama, Indie, Black-and-white
# 2     Swashbuckler films, Silent film, Drama, Adventure
# 6     Silent film, Adventure, Children's/Family, Bla...
# 7                                           Silent film
# ...                                                 ...
# 1956                                              Drama
# 1965                                              Drama
# 1966                       Mystery, Romance Film, Drama
# 1968                                  Thriller, Mystery
# 1971  Family Film, Drama, Romance Film, Musical, Ani...
#
#                      author_book year_book
# 0                  L. Frank Baum      1900
# 1              Gerhart Hauptmann      1912
# 2               Sir Walter Scott      1820
# 6                  L. Frank Baum      1900
# 7                 Upton Sinclair      1906
# ...                          ...       ...
# 1956    Pierre Drieu La Rochelle      1931
# 1965               Luo Guanzhong       NaN
# 1966  Pierre Choderlos de Laclos      1782
# 1968               Miyuki Miyabe      1992
# 1971                 Victor Hugo      1482
#
# [1960 rows x 11 columns]

# %%
def merge_imdb_ratings(df):
    imdb_ratings = pd.read_csv(data_folder + "title.ratings.tsv", sep='\t', header=0, names=['imdbID', 'rating', 'numVotes'])
    
    imdb_ratings['rating'] = pd.to_numeric(imdb_ratings['rating'])
    imdb_ratings['numVotes'] = pd.to_numeric(imdb_ratings['numVotes'])
    imdb_ratings = imdb_ratings.dropna()

    return pd.merge(df, imdb_ratings, how='inner', on=['imdbID'])

merged_imdb = merge_imdb_ratings(merged_imdb_id)
merged_imdb
# Out:
#          imdbID  isAdult                   movie_name  movie_date  \
# 0     tt0000679        0  thefairylogueandradio-plays        1908
# 1     tt0002646        0                     atlantis        1913
# 2     tt0003022        0                      ivanhoe        1913
# 3     tt0004099        0  hismajesty,thescarecrowofoz        1914
# 4     tt0004182        0                    thejungle        1914
# ...         ...      ...                          ...         ...
# 1935  tt1736633        0              oslo,august31st        2011
# 1936  tt2063013        0                 theassassins        2012
# 1937  tt2071441        0            dangerousliaisons        2012
# 1938  tt2308725        0                     helpless        2012
# 1939  tt9799878        0      thehunchbackofnotredame        1996
#
#        box_office  runtime                             language  \
# 0             NaN    120.0                     English Language
# 1             NaN    113.0    English Language, Danish Language
# 2             NaN      NaN        Silent film, English Language
# 3             NaN     60.0                     English Language
# 4             NaN      NaN        Silent film, English Language
# ...           ...      ...                                  ...
# 1935          NaN     95.0                   Norwegian Language
# 1936          NaN      NaN                    Standard Mandarin
# 1937          NaN    110.0  English Language, Standard Mandarin
# 1938   16175929.0    117.0                      Korean Language
# 1939  325338851.0     90.0                     English Language
#
#                           countries  \
# 0          United States of America
# 1                           Denmark
# 2          United States of America
# 3          United States of America
# 4                               NaN
# ...                             ...
# 1935                         Norway
# 1936                          China
# 1937  Singapore, South Korea, China
# 1938                    South Korea
# 1939       United States of America
#
#                                                  genres  \
# 0                          Silent film, Black-and-white
# 1            Silent film, Drama, Indie, Black-and-white
# 2     Swashbuckler films, Silent film, Drama, Adventure
# 3     Silent film, Adventure, Children's/Family, Bla...
# 4                                           Silent film
# ...                                                 ...
# 1935                                              Drama
# 1936                                              Drama
# 1937                       Mystery, Romance Film, Drama
# 1938                                  Thriller, Mystery
# 1939  Family Film, Drama, Romance Film, Musical, Ani...
#
#                      author_book year_book  rating  numVotes
# 0                  L. Frank Baum      1900     5.2        76
# 1              Gerhart Hauptmann      1912     6.5       500
# 2               Sir Walter Scott      1820     5.6        97
# 3                  L. Frank Baum      1900     5.3       533
# 4                 Upton Sinclair      1906     6.8        70
# ...                          ...       ...     ...       ...
# 1935    Pierre Drieu La Rochelle      1931     7.6     30513
# 1936               Luo Guanzhong       NaN     5.5      2147
# 1937  Pierre Choderlos de Laclos      1782     6.0      2092
# 1938               Miyuki Miyabe      1992     6.7      2642
# 1939                 Victor Hugo      1482     1.9        82
#
# [1940 rows x 13 columns]

# %%
print('lines dropped during merge with IMDB: ', len(merged_cmu) - len(merged_imdb))
merged_imdb.to_csv('merge_imdb.csv', index=False)
merged_imdb
# Out:
# lines dropped during merge with IMDB:  386
#          imdbID  isAdult                   movie_name  movie_date  \
# 0     tt0000679        0  thefairylogueandradio-plays        1908
# 1     tt0002646        0                     atlantis        1913
# 2     tt0003022        0                      ivanhoe        1913
# 3     tt0004099        0  hismajesty,thescarecrowofoz        1914
# 4     tt0004182        0                    thejungle        1914
# ...         ...      ...                          ...         ...
# 1935  tt1736633        0              oslo,august31st        2011
# 1936  tt2063013        0                 theassassins        2012
# 1937  tt2071441        0            dangerousliaisons        2012
# 1938  tt2308725        0                     helpless        2012
# 1939  tt9799878        0      thehunchbackofnotredame        1996
#
#        box_office  runtime                             language  \
# 0             NaN    120.0                     English Language
# 1             NaN    113.0    English Language, Danish Language
# 2             NaN      NaN        Silent film, English Language
# 3             NaN     60.0                     English Language
# 4             NaN      NaN        Silent film, English Language
# ...           ...      ...                                  ...
# 1935          NaN     95.0                   Norwegian Language
# 1936          NaN      NaN                    Standard Mandarin
# 1937          NaN    110.0  English Language, Standard Mandarin
# 1938   16175929.0    117.0                      Korean Language
# 1939  325338851.0     90.0                     English Language
#
#                           countries  \
# 0          United States of America
# 1                           Denmark
# 2          United States of America
# 3          United States of America
# 4                               NaN
# ...                             ...
# 1935                         Norway
# 1936                          China
# 1937  Singapore, South Korea, China
# 1938                    South Korea
# 1939       United States of America
#
#                                                  genres  \
# 0                          Silent film, Black-and-white
# 1            Silent film, Drama, Indie, Black-and-white
# 2     Swashbuckler films, Silent film, Drama, Adventure
# 3     Silent film, Adventure, Children's/Family, Bla...
# 4                                           Silent film
# ...                                                 ...
# 1935                                              Drama
# 1936                                              Drama
# 1937                       Mystery, Romance Film, Drama
# 1938                                  Thriller, Mystery
# 1939  Family Film, Drama, Romance Film, Musical, Ani...
#
#                      author_book year_book  rating  numVotes
# 0                  L. Frank Baum      1900     5.2        76
# 1              Gerhart Hauptmann      1912     6.5       500
# 2               Sir Walter Scott      1820     5.6        97
# 3                  L. Frank Baum      1900     5.3       533
# 4                 Upton Sinclair      1906     6.8        70
# ...                          ...       ...     ...       ...
# 1935    Pierre Drieu La Rochelle      1931     7.6     30513
# 1936               Luo Guanzhong       NaN     5.5      2147
# 1937  Pierre Choderlos de Laclos      1782     6.0      2092
# 1938               Miyuki Miyabe      1992     6.7      2642
# 1939                 Victor Hugo      1482     1.9        82
#
# [1940 rows x 13 columns]
